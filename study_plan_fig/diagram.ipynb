# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rng = np.arange(-.01, 1, 0.01)
fig = plt.figure()
plt.plot(rng, 500*np.exp(-5*rng))
plt.plot(rng, [250]*len(rng))
fig.savefig("./test.svg")
