# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind
# from main import generate_pairs_indices

# %%
from itertools import combinations
def generate_pairs_indices(data):

    pairs_elements = []
    for i, j in combinations(data, 2):
        pairs_elements.append((i, j))

    return pairs_elements

# %%
# !pwd
# Out:
# /home/niusha/Documents/Codes/p-value_metric_project/analysis

# %%
roi_df = pd.read_csv("../study_files/roi_data.csv", index_col=0)
roi_df.head()
# Out:
#    Study Date             Description  \
# 0   6/12/2013           MPRAGE GRAPPA
# 1   5/15/2013           MPRAGE GRAPPA
# 2  12/06/2012           MPRAGE GRAPPA
# 3   1/14/2014           MPRAGE GRAPPA
# 4   6/20/2021  3D-T1-weighted_SAGITAL
#
#                                     Imaging Protocol EVENT_ID   PATNO  \
# 0  Acquisition Plane=SAGITTAL;Field Strength=3.0;...      V04    3777
# 1  Acquisition Plane=SAGITTAL;Field Strength=3.0;...      V06    3107
# 2  Acquisition Plane=SAGITTAL;Field Strength=3.0;...      V06    3557
# 3  Acquisition Plane=SAGITTAL;Field Strength=3.0;...      V04    3834
# 4  Acquisition Plane=SAGITTAL;Field Strength=3.0;...       BL  101279
#
#    PRIMDIAG  OTHNEURO  AGE_AT_VISIT  SEX  BIRTHDT  ...  \
# 0         1       NaN          63.0    1  01/1950  ...
# 1         1       NaN          71.7    1  09/1941  ...
# 2         1       NaN          61.0    1  12/1951  ...
# 3         1       NaN          69.7    1  06/1944  ...
# 4         1       NaN          69.9    1  07/1951  ...
#
#    Right-Accumbens-area_meanT1T2  Right-Accumbens-area_change_pred  \
# 0                     -34.134558                         23.987596
# 1                     -26.314785                         11.760080
# 2                     176.436737                        -75.743380
# 3                     -45.865052                        -33.504822
# 4                     -99.218387                         29.834644
#
#    Left-Accumbens-area_first_pred  Left-Accumbens-area_second_pred  \
# 0                      -16.225904                       -18.691073
# 1                      -94.788635                       -28.588956
# 2                      136.891671                        78.691265
# 3                      149.828201                        24.905254
# 4                      -65.268562                       -62.266879
#
#    Left-Accumbens-area_change Left-Accumbens-area_meanT1T2  \
# 0                   -2.465169                   -17.458488
# 1                   66.199679                   -61.688795
# 2                  -58.200406                   107.791468
# 3                 -124.922947                    87.366728
# 4                    3.001683                   -63.767721
#
#    Left-Accumbens-area_change_pred  durationT2_T1_y  thickness_change  \
# 0                        -2.374909         3.082883          0.012453
# 1                        66.518608         1.998672          0.013867
# 2                       -58.757685         2.168422          0.022041
# 3                      -125.374631         3.000746          0.001531
# 4                         3.331360         1.333361          0.009776
#
#    thickness_change_pct
# 0             -1.581534
# 1             -1.151417
# 2             -2.078437
# 3             -0.183792
# 4             -0.514048
#
# [5 rows x 222 columns]

# %%
roi_df.describe()
# Out:
#                PATNO   PRIMDIAG  OTHNEURO  AGE_AT_VISIT        SEX    EDUCYRS  \
# count      43.000000  43.000000       0.0     43.000000  43.000000  42.000000
# mean    21952.837209   7.697674       NaN     65.830233   0.813953  15.190476
# std     37481.178255   7.986700       NaN      7.399020   0.393750   2.520531
# min      3107.000000   1.000000       NaN     42.800000   0.000000  11.000000
# 25%      3389.500000   1.000000       NaN     61.350000   1.000000  13.250000
# 50%      3777.000000   1.000000       NaN     67.300000   1.000000  16.000000
# 75%      4025.000000  17.000000       NaN     70.950000   1.000000  16.000000
# max    110212.000000  17.000000       NaN     79.200000   1.000000  22.000000
#
#           COHORT  PDDXDT   COGSTATE  CMTRT  ...  \
# count  43.000000     0.0  30.000000    0.0  ...
# mean    1.418605     NaN   1.366667    NaN  ...
# std     0.499169     NaN   0.490133    NaN  ...
# min     1.000000     NaN   1.000000    NaN  ...
# 25%     1.000000     NaN   1.000000    NaN  ...
# 50%     1.000000     NaN   1.000000    NaN  ...
# 75%     2.000000     NaN   2.000000    NaN  ...
# max     2.000000     NaN   2.000000    NaN  ...
#
#        Right-Accumbens-area_meanT1T2  Right-Accumbens-area_change_pred  \
# count                   4.300000e+01                      4.300000e+01
# mean                   -2.974365e-14                     -1.652425e-16
# std                     1.104593e+02                      4.195907e+01
# min                    -2.295855e+02                     -8.712425e+01
# 25%                    -7.349443e+01                     -2.440882e+01
# 50%                    -1.488121e+01                     -7.353741e+00
# 75%                     5.178139e+01                      2.193879e+01
# max                     3.171106e+02                      1.231742e+02
#
#        Left-Accumbens-area_first_pred  Left-Accumbens-area_second_pred  \
# count                    4.300000e+01                        43.000000
# mean                    -1.361598e-13                         0.000000
# std                      1.122412e+02                       112.798353
# min                     -2.222510e+02                      -181.259834
# 25%                     -7.483637e+01                       -78.865963
# 50%                     -2.920285e+01                       -18.691073
# 75%                      7.310494e+01                        72.648378
# max                      2.490420e+02                       269.713987
#
#        Left-Accumbens-area_change  Left-Accumbens-area_meanT1T2  \
# count                4.300000e+01                  4.300000e+01
# mean                 1.384732e-13                 -7.006282e-14
# std                  4.622605e+01                  1.101207e+02
# min                 -1.249229e+02                 -2.017554e+02
# 25%                 -2.512823e+01                 -8.365102e+01
# 50%                  3.095822e+00                 -1.825209e+01
# 75%                  2.988453e+01                  7.742308e+01
# max                  9.332525e+01                  2.593780e+02
#
#        Left-Accumbens-area_change_pred  durationT2_T1_y  thickness_change  \
# count                     4.300000e+01        43.000000         43.000000
# mean                     -8.881784e-16         1.525460          0.003738
# std                       4.622254e+01         0.555304          0.022489
# min                      -1.253746e+02         0.585912         -0.062795
# 25%                      -2.471190e+01         1.086949         -0.010664
# 50%                       3.331360e+00         1.327885          0.005569
# 75%                       3.016035e+01         1.998672          0.015215
# max                       9.311341e+01         3.082883          0.048261
#
#        thickness_change_pct
# count             43.000000
# mean              -0.260776
# std                1.389357
# min               -3.351894
# 25%               -1.116810
# 50%               -0.249708
# 75%                0.558940
# max                3.719637
#
# [8 rows x 199 columns]

# %%
ROIs = [
    "Thalamus",
    "Caudate",
    "Putamen",
    "Pallidum",
    "Hippocampus",
    "Amygdala",
    "Accumbens-area",
]

target_columns = ["thickness_change"] + [region+"_change_pred" for region in ROIs]

# %%
#get specific columns of the dataframe
target_df = roi_df.loc[:, target_columns]
PD_MCI_df = target_df.loc[roi_df["dx_group"] == "PD-MCI"]
PD_non_MCI_df = target_df.loc[roi_df["dx_group"] == "PD-non-MCI"]
HC_df = target_df.loc[roi_df["dx_group"] == "HC"]

# %%
# pairs = generate_pairs_indices([PD_MCI_df, PD_non_MCI_df, HC_df]])
# test_results = []
# for pair in pairs:
#     column_results = []
#     for region in target_columns:
#         _, p = ttest_ind(pair[0][region], pair[1][region])
#         column_results.append(p)
#     pd.Series(column_results, index=target_columns)

# %%
pairs = generate_pairs_indices(roi_df["dx_group"].unique())
test_results = []
for pair in pairs:
    column_results = []
    for region in target_columns:
        _, p = ttest_ind(roi_df.loc[roi_df["dx_group"] == pair[0]][region],
                                roi_df.loc[roi_df["dx_group"] == pair[1]][region])
        column_results.append(p)
    test_results.append(pd.Series(column_results, index=target_columns, name= pair[0] + "_vs_" + pair[1]))
volumetric_results = pd.concat(test_results, axis=1)

# %%
pairs
# Out:
# [('PD-MCI', 'PD-non-MCI'), ('PD-MCI', 'HC'), ('PD-non-MCI', 'HC')]

# %%
volumetric_results.to_csv(path_or_buf="../study_files/volumetric_changes_pvalues.csv",
                         header=True, index=True)

# %%
volumetric_results
# Out:
#                             PD-MCI_vs_PD-non-MCI  PD-MCI_vs_HC  \
# thickness_change                        0.443169      0.997976
# Thalamus_change_pred                    0.012854      0.280367
# Caudate_change_pred                     0.632498      0.561301
# Putamen_change_pred                     0.209674      0.257905
# Pallidum_change_pred                    0.546732      0.825296
# Hippocampus_change_pred                 0.426830      0.222348
# Amygdala_change_pred                    0.574215      0.200023
# Accumbens-area_change_pred              0.809184      0.520146
#
#                             PD-non-MCI_vs_HC
# thickness_change                    0.503756
# Thalamus_change_pred                0.088426
# Caudate_change_pred                 0.952774
# Putamen_change_pred                 0.015019
# Pallidum_change_pred                0.132805
# Hippocampus_change_pred             0.742446
# Amygdala_change_pred                0.504155
# Accumbens-area_change_pred          0.576393

# %% [markdown]
# - Don't they need multiple comparison correction?
# - Numbers are close but not the same. (this was because I used `pred_pct` columns instead of `pred`)

# %%
roi_df["dx_group"].value_counts()
# Out:
# HC            18
# PD-non-MCI    15
# PD-MCI        10
# Name: dx_group, dtype: int64

# %%
n_regions = len(target_columns)

MCIvsHC_stats = np.zeros((n_regions, 1000, 2))
MCIvsnonMCI_stats = np.zeros((n_regions, 1000, 2))
nonMCIvsHC_stats = np.zeros((n_regions, 1000, 2))

PD_MCI_index = PD_MCI_df.index.tolist()
PD_non_MCI_index = PD_non_MCI_df.index.tolist()
HC_index = HC_df.index.tolist()

n_PD_MCI = len(PD_MCI_index)
n_PD_non_MCI = len(PD_non_MCI_index)
n_HC = len(HC_index)

# %%
n_regions
# Out:
# 8

# %%
for itr in range(1000):

    MCI_sample = list(np.random.choice(PD_MCI_index, n_PD_MCI, replace=True))
    nonMCI_sample = list(np.random.choice(PD_non_MCI_index, n_PD_non_MCI, replace=True))
    HC_sample = list(np.random.choice(HC_index, n_HC, replace=True))

    for i in range(n_regions):
        region = target_columns[i]
        MCIvsnonMCI_stats[i][itr] = ttest_ind(PD_MCI_df[region].loc[MCI_sample], PD_non_MCI_df[region].loc[nonMCI_sample])
        nonMCIvsHC_stats[i][itr] = ttest_ind(HC_df[region].loc[HC_sample], PD_non_MCI_df[region].loc[nonMCI_sample])
        MCIvsHC_stats[i][itr] = ttest_ind(PD_MCI_df[region].loc[MCI_sample], HC_df[region].loc[HC_sample])

# %%
target_columns[1]
# Out:
# 'Thalamus_change_pred'

# %%
sum(MCIvsnonMCI_stats[1, :,1] < 0.05) / 1000
# Out:
# 0.833

# %%
MCIvsnonMCI_stats[1, ...].shape
f, ax = plt.subplots(1, 2, figsize=(10, 5))
f.suptitle('Thalamus volumetric change comparison: MCI vs non-MCI s')
ax[0].set_title(" t-stat")
ax[0] = sns.histplot(MCIvsnonMCI_stats[1, :, 0], ax=ax[0])
ax[1].set_title(" p-value")
ax[1] = sns.histplot(MCIvsnonMCI_stats[1, :, 1], ax=ax[1])
ax[0].spines['top'].set_visible(False)
ax[0].spines['right'].set_visible(False)
ax[1].spines['top'].set_visible(False)
ax[1].spines['right'].set_visible(False)

# %%
target_columns[5]
# Out:
# 'Hippocampus_change_pred'

# %%
f, ax = plt.subplots(1, 2, figsize=(10, 5))
f.suptitle('Hippocampus volumetric change comparison: non-MCI vs HC')
ax[0].set_title(" t-stat")
ax[0] = sns.histplot(nonMCIvsHC_stats[5, :, 0], ax=ax[0])
ax[1].set_title(" p-value")
ax[1] = sns.histplot(nonMCIvsHC_stats[5, :, 1], ax=ax[1])
ax[0].spines['top'].set_visible(False)
ax[0].spines['right'].set_visible(False)
ax[1].spines['top'].set_visible(False)
ax[1].spines['right'].set_visible(False)

# %%
sum(nonMCIvsHC_stats[5, :, 1] < 0.05)/1000
# Out:
# 0.077

# %%
titles = ["PD MCI vs PD non-MCI",  "PD MCI vs HC", "PD non-MCI vs HC"]
stats = [MCIvsnonMCI_stats, MCIvsHC_stats, nonMCIvsHC_stats]

for i in range(3):
    f, ax = plt.subplots(nrows=2, ncols=n_regions, figsize=(30, 15))
    f.suptitle(titles[i])
    for j in range(n_regions):
        ax[0,j].set_title(target_columns[j] + " t-stat")
        ax[0,j] = sns.histplot(stats[i][j, :, 0], ax=ax[0,j])
        ax[1,j].set_title(target_columns[j] + " p-value")
        ax[1,j] = sns.histplot(stats[i][j, :, 1], ax=ax[1,j])

# %%
# for j in range(n_regions):    
#     for i in range(3):
#         print(titles[i], target_columns[j], "t-stat:", np.mean(stats[i][j, :, 0]), "p-value:", np.mean(stats[i][j, :, 1]))

# %%
data = {titles[i]: stats[i][:,:,1].mean(axis=1) for i in range(3)}
df = pd.DataFrame(data)
df.index = target_columns
df
# Out:
#                             PD MCI vs PD non-MCI  PD MCI vs HC  \
# thickness_change                        0.401016      0.560973
# Thalamus_change_pred                    0.030066      0.325713
# Caudate_change_pred                     0.458123      0.418888
# Putamen_change_pred                     0.286149      0.329927
# Pallidum_change_pred                    0.415241      0.414409
# Hippocampus_change_pred                 0.401894      0.298158
# Amygdala_change_pred                    0.427618      0.280298
# Accumbens-area_change_pred              0.471713      0.434154
#
#                             PD non-MCI vs HC
# thickness_change                    0.405846
# Thalamus_change_pred                0.175645
# Caudate_change_pred                 0.461035
# Putamen_change_pred                 0.054074
# Pallidum_change_pred                0.227120
# Hippocampus_change_pred             0.474402
# Amygdala_change_pred                0.429904
# Accumbens-area_change_pred          0.446315

# %%
data = {titles[i]: np.median(stats[i][:,:,1],axis=1) for i in range(3)}
df = pd.DataFrame(data)
df.index = target_columns

# %%
df
# Out:
#                             MCI vs non-MCI  non-MCI vs HC  MCI vs HC
# thickness_change                  0.403467       0.383619   0.588102
# Thalamus_change_pred              0.007773       0.064798   0.255898
# Caudate_change_pred               0.415665       0.455398   0.338797
# Putamen_change_pred               0.174470       0.011049   0.218869
# Pallidum_change_pred              0.373801       0.108579   0.361621
# Hippocampus_change_pred           0.362184       0.492238   0.187595
# Amygdala_change_pred              0.389653       0.389520   0.182354
# Accumbens-area_change_pred        0.435817       0.403451   0.371359

# %%
target_columns.pop(0)
# Out:
# 'thickness_change'

# %%
target_correlation = ["MCATOT_diff"]
for side in ["Left-", "Right-"]:
    for region in target_columns:
        target_correlation.append(side+region)

# %%
target_correlation
# Out:
# ['MCATOT_diff',
#  'Left-Thalamus_change_pred',
#  'Left-Caudate_change_pred',
#  'Left-Putamen_change_pred',
#  'Left-Pallidum_change_pred',
#  'Left-Hippocampus_change_pred',
#  'Left-Amygdala_change_pred',
#  'Left-Accumbens-area_change_pred',
#  'Right-Thalamus_change_pred',
#  'Right-Caudate_change_pred',
#  'Right-Putamen_change_pred',
#  'Right-Pallidum_change_pred',
#  'Right-Hippocampus_change_pred',
#  'Right-Amygdala_change_pred',
#  'Right-Accumbens-area_change_pred']

# %%
n_target_correlation = len(target_correlation)
target_corr_df = roi_df.loc[PD_MCI_index + PD_non_MCI_index][target_correlation]

# %%
target_corr_df
# Out:
#     MCATOT_diff  Left-Thalamus_change_pred  Left-Caudate_change_pred  \
# 0           0.0                -338.972364               -102.744504
# 1          -5.0                 -26.987301                -60.188294
# 2          -3.0                -303.965050                216.797471
# 3          -1.0                -212.342312                469.108889
# 4           3.0                -221.504132               -105.287468
# 5           3.0                 -19.161845               -108.444997
# 6           0.0                  74.372176                -85.956216
# 7           0.0                -168.495586                 23.241073
# 8          -1.0                 -49.045132                -43.963616
# 9           2.0                  53.588982                 74.737215
# 10          1.0                 994.269589                114.552622
# 11         -3.0                  42.237409                -66.706273
# 12         -2.0                   2.835775               -178.662912
# 13         -1.0                   6.522361                -87.230526
# 14         -2.0                 -53.410468               -150.572120
# 15          2.0                 105.777308                 50.251090
# 16         -4.0                -217.644804                -39.621308
# 17         -1.0                 106.870344                126.972128
# 18         -2.0                 244.511232                102.171721
# 19         -1.0                 124.868679                -55.963867
# 20          1.0                 255.353529                 90.511133
# 21          0.0                 106.960804                -20.521239
# 22         -4.0                 102.205357                -27.198611
# 23          1.0                  37.333494                -11.501437
# 24         -2.0                 -36.424927                 48.322053
#
#     Left-Putamen_change_pred  Left-Pallidum_change_pred  \
# 0                -120.216881                  49.829713
# 1                 -28.276075                 -36.062727
# 2                  -8.263377                  24.798579
# 3                 409.023487                  45.599395
# 4                 -79.547251                   5.115033
# 5                  55.019095                 -77.225584
# 6                 -53.860435                  22.220163
# 7                 -83.932051                 -44.588200
# 8                  66.149619                 -42.285764
# 9                -120.671993                  63.717325
# 10                334.188175                -130.580961
# 11                 47.854408                 -81.221006
# 12                 22.577696                  52.386658
# 13                -89.273597                 141.324226
# 14                 90.660366                  -9.187859
# 15                 93.738414                  77.597371
# 16                -14.092593                  19.364811
# 17                129.033946                   7.807000
# 18                -36.327052                  29.733809
# 19                -88.937291                 165.690360
# 20                -42.764176                  20.817704
# 21               -154.302417                  29.943266
# 22                -14.950951                 -28.033142
# 23                 37.387669                  39.324772
# 24                171.683675                   4.921125
#
#     Left-Hippocampus_change_pred  Left-Amygdala_change_pred  \
# 0                     -80.761183                 -83.989064
# 1                      10.506167                 -27.267198
# 2                       2.968788                 -16.153489
# 3                    -142.231078                 -62.072238
# 4                     -56.252886                  -1.387287
# 5                    -111.220447                  46.242610
# 6                      56.527422                  39.422138
# 7                     -85.209693                -154.299409
# 8                      75.966108                 -98.194810
# 9                     173.062458                  37.895995
# 10                      1.140832                  81.948370
# 11                    -12.817039                  81.821402
# 12                     28.634505                 -14.257855
# 13                    -38.655815                  34.849863
# 14                    -23.346943                 -96.735830
# 15                     36.551299                 121.713335
# 16                    -54.991056                 -49.958624
# 17                     82.826216                 182.740717
# 18                    183.705431                -105.261584
# 19                   -199.427642                  62.639059
# 20                    194.561617                  86.054387
# 21                   -151.785926                -168.708396
# 22                    -13.922548                  39.310523
# 23                   -100.691620                  61.094260
# 24                     -1.162527                 -77.067504
#
#     Left-Accumbens-area_change_pred  Right-Thalamus_change_pred  \
# 0                         -2.374909                 -380.113964
# 1                         66.518608                  -59.241516
# 2                        -58.757685                 -150.158728
# 3                       -125.374631                 -344.222888
# 4                          3.331360                 -125.594682
# 5                         42.034197                 -156.632348
# 6                         28.658559                  306.508472
# 7                         11.194646                 -104.093715
# 8                         68.352963                 -142.046602
# 9                        -65.057737                  114.333675
# 10                        93.113410                  527.833682
# 11                        27.670809                  148.907163
# 12                       -23.726055                  -52.980853
# 13                       -28.705736                  -89.636625
# 14                       -67.887068                  -18.215536
# 15                       -37.491930                   62.727497
# 16                        19.330967                    3.753110
# 17                         2.736114                  -21.538056
# 18                         4.941435                   70.279245
# 19                       -97.191399                  209.035516
# 20                       -19.120714                  360.583404
# 21                        41.934055                 -123.725347
# 22                        12.136014                  324.000102
# 23                        51.752697                 -142.996896
# 24                       -44.294608                  105.760111
#
#     Right-Caudate_change_pred  Right-Putamen_change_pred  \
# 0                  -72.965330                 -35.594857
# 1                 -136.624953                  64.729076
# 2                  278.768253                 -28.406013
# 3                  124.843645                 -22.141660
# 4                  -22.804785                  36.712358
# 5                  -40.363482                  19.387421
# 6                  -53.493339                -127.396699
# 7                 -100.167016                 -47.376873
# 8                   90.840445                -141.848127
# 9                    9.617132                  94.519424
# 10                 113.373077                 546.724132
# 11                 -44.118661                 -62.340190
# 12                -471.662044                 451.942946
# 13                 -35.078200                -137.870310
# 14                -104.020989                 -64.849700
# 15                  54.492109                  11.413079
# 16                  47.959877                 -65.335594
# 17                  22.944353                  28.546153
# 18                  72.544263                  81.788535
# 19                  71.766416                 187.803153
# 20                  76.226361                  17.793851
# 21                 -55.177339                -110.027773
# 22                 -23.854798                  91.483581
# 23                  98.844987                  -7.722092
# 24                 123.836364                 269.914957
#
#     Right-Pallidum_change_pred  Right-Hippocampus_change_pred  \
# 0                   -61.391558                    -122.193717
# 1                     2.540188                     -63.760316
# 2                    73.670288                     -23.306356
# 3                   221.928803                     -77.477546
# 4                   -71.291984                    -109.168589
# 5                   220.479017                     -12.927258
# 6                  -600.158736                      47.908444
# 7                   173.601350                     -16.015340
# 8                    67.455147                      45.843938
# 9                  -153.480057                     -16.547022
# 10                   40.374817                    -157.550461
# 11                  -82.800961                      21.812953
# 12                  -36.272680                      90.377067
# 13                  -83.531628                     -29.097573
# 14                  -47.843628                      47.279457
# 15                   18.549132                     117.662871
# 16                  -44.644955                     -67.967436
# 17                   37.216265                      96.343293
# 18                   10.704916                     115.336382
# 19                   87.477621                     -47.645718
# 20                  -22.709119                      75.714551
# 21                   17.785735                    -180.788990
# 22                   44.855863                     -14.360528
# 23                  120.312975                     -16.568887
# 24                   77.032793                      73.415239
#
#     Right-Amygdala_change_pred  Right-Accumbens-area_change_pred
# 0                  -162.896056                         23.987596
# 1                   113.308985                         11.760080
# 2                    49.778933                        -75.743380
# 3                    35.010611                        -33.504822
# 4                    71.858709                         29.834644
# 5                  -106.239814                         14.303015
# 6                   -14.303339                         23.671215
# 7                   -94.393879                         -6.809535
# 8                   -74.862905                        -15.072985
# 9                   113.972927                        -24.822059
# 10                  -12.178764                         -9.777441
# 11                  -75.276294                        -33.663672
# 12                  110.464226                         -3.753279
# 13                  -20.428249                        -37.464283
# 14                   -3.887574                         -9.913104
# 15                  -13.234083                         38.495356
# 16                   82.438865                          8.518205
# 17                   27.678458                        -15.052704
# 18                   30.894601                        123.174203
# 19                 -170.747415                         91.609190
# 20                  -40.673708                        -23.097745
# 21                 -278.273197                        -47.909934
# 22                    0.226126                        -37.034642
# 23                   27.419631                        -87.124249
# 24                   29.177007                         46.094248

# %%
MCI_corr = np.zeros((n_target_correlation-1, 1000, 2))
non_MCI_corr = np.zeros((n_target_correlation-1, 1000, 2))
PD_corr = np.zeros((n_target_correlation-1, 1000, 2))

# %%
from scipy.stats import pearsonr

# %%
for itr in range(1000):
    MCI_sample = list(np.random.choice(PD_MCI_index, n_PD_MCI, replace=True))
    non_MCI_sample = list(np.random.choice(PD_non_MCI_index, n_PD_non_MCI, replace=True))
    PD_sample = list(np.random.choice(PD_MCI_index+PD_non_MCI_index, n_PD_MCI+n_PD_non_MCI, replace=True))

    for i in range(1,n_target_correlation):
        region = target_correlation[i]
        MCI_corr[i-1][itr] = pearsonr(target_corr_df[region].loc[MCI_sample], target_corr_df["MCATOT_diff"].loc[MCI_sample])
        non_MCI_corr[i-1][itr] = pearsonr(target_corr_df[region].loc[non_MCI_sample], target_corr_df["MCATOT_diff"].loc[non_MCI_sample])
        PD_corr[i-1][itr] = pearsonr(target_corr_df[region].loc[PD_sample], target_corr_df["MCATOT_diff"].loc[PD_sample])

# %%
corr_result = [MCI_corr, non_MCI_corr, PD_corr]
corr_title = ["MCI", "non-MCI", "All PD"]
for cohort_idx in range(3):
    f, ax = plt.subplots(nrows=4, ncols=7, figsize=(30, 30))
    f.suptitle(corr_title[cohort_idx])
    for j in range(int((n_target_correlation-1)/2)):
        for i,k in zip([0,2], [0,7]):
            ax[i,j].set_title(target_correlation[j+1+k]+ " corr")
            ax[i,j] = sns.histplot(corr_result[cohort_idx][j+k, :, 0], ax=ax[i,j])
            ax[i+1,j].set_title(target_correlation[j+1+k] + " p-value")
            ax[i+1,j] = sns.histplot(corr_result[cohort_idx][j+k, :, 1], ax=ax[i+1,j])

# %%
k=1

# %%
stats_names = ["corr", "p-value"]
corr_summary = {corr_title[i] + " " + stats_names[j]: np.median(corr_result[i][:,:,j],axis=1) for i in range(3) for j in range(2)}
df_corr_summary = pd.DataFrame(corr_summary)
df_corr_summary.index = target_correlation[1:]

# %%
df_corr_summary
# Out:
#                                   MCI corr  MCI p-value  non-MCI corr  \
# Left-Thalamus_change_pred         0.164465     0.487006      0.507620
# Left-Caudate_change_pred         -0.312019     0.366082      0.417462
# Left-Putamen_change_pred         -0.196059     0.558353      0.182200
# Left-Pallidum_change_pred         0.010399     0.479904      0.168325
# Left-Hippocampus_change_pred     -0.101006     0.537831      0.058102
# Left-Amygdala_change_pred         0.367704     0.287793      0.361985
# Left-Accumbens-area_change_pred  -0.087759     0.491785      0.126523
# Right-Thalamus_change_pred        0.098122     0.684763      0.059630
# Right-Caudate_change_pred        -0.181059     0.375774      0.307006
# Right-Putamen_change_pred         0.161752     0.478239      0.079841
# Right-Pallidum_change_pred       -0.080379     0.665363      0.358557
# Right-Hippocampus_change_pred    -0.011156     0.599367     -0.061143
# Right-Amygdala_change_pred       -0.263447     0.352583     -0.286855
# Right-Accumbens-area_change_pred  0.362156     0.276155     -0.141700
#
#                                   non-MCI p-value  All PD corr  All PD p-value
# Left-Thalamus_change_pred                0.053402     0.199240        0.314858
# Left-Caudate_change_pred                 0.121561     0.016869        0.617073
# Left-Putamen_change_pred                 0.435066    -0.029263        0.627378
# Left-Pallidum_change_pred                0.419164     0.053766        0.536129
# Left-Hippocampus_change_pred             0.555350    -0.006346        0.605783
# Left-Amygdala_change_pred                0.183663     0.245123        0.237606
# Left-Accumbens-area_change_pred          0.490866     0.023735        0.550426
# Right-Thalamus_change_pred               0.429659    -0.024094        0.558664
# Right-Caudate_change_pred                0.265696     0.094423        0.486419
# Right-Putamen_change_pred                0.518008     0.015344        0.624302
# Right-Pallidum_change_pred               0.189397    -0.000975        0.618465
# Right-Hippocampus_change_pred            0.478780    -0.099790        0.510392
# Right-Amygdala_change_pred               0.299009    -0.240527        0.240796
# Right-Accumbens-area_change_pred         0.495491     0.036548        0.579272

# %%
stats_names = ["corr", "p-value"]
corr_summary = {corr_title[i] + " " + stats_names[j]: np.mean(corr_result[i][:,:,j],axis=1) for i in range(3) for j in range(2)}
df_corr_summary = pd.DataFrame(corr_summary)
df_corr_summary.index = target_correlation[1:]
df_corr_summary
# Out:
#                                   MCI corr  MCI p-value  non-MCI corr  \
# Left-Thalamus_change_pred         0.160529     0.495359      0.498947
# Left-Caudate_change_pred         -0.312015     0.403513      0.407754
# Left-Putamen_change_pred         -0.204075     0.532758      0.148197
# Left-Pallidum_change_pred         0.015973     0.485972      0.175819
# Left-Hippocampus_change_pred     -0.119448     0.523688      0.045589
# Left-Amygdala_change_pred         0.351636     0.342584      0.343391
# Left-Accumbens-area_change_pred  -0.055135     0.479945      0.111242
# Right-Thalamus_change_pred        0.103883     0.647565      0.033804
# Right-Caudate_change_pred        -0.178636     0.394083      0.312186
# Right-Putamen_change_pred         0.180118     0.445244      0.068565
# Right-Pallidum_change_pred       -0.088178     0.606649      0.334427
# Right-Hippocampus_change_pred    -0.018702     0.573772     -0.054343
# Right-Amygdala_change_pred       -0.236532     0.395335     -0.278842
# Right-Accumbens-area_change_pred  0.371976     0.337000     -0.135725
#
#                                   non-MCI p-value  All PD corr  All PD p-value
# Left-Thalamus_change_pred                0.113657     0.185883        0.382665
# Left-Caudate_change_pred                 0.183531     0.018813        0.586459
# Left-Putamen_change_pred                 0.454646    -0.030413        0.604873
# Left-Pallidum_change_pred                0.440765     0.060016        0.518584
# Left-Hippocampus_change_pred             0.544612    -0.011012        0.572348
# Left-Amygdala_change_pred                0.278663     0.242481        0.316429
# Left-Accumbens-area_change_pred          0.486001     0.026064        0.538239
# Right-Thalamus_change_pred               0.451942    -0.029440        0.551004
# Right-Caudate_change_pred                0.308401     0.084758        0.497804
# Right-Putamen_change_pred                0.513891     0.017616        0.606992
# Right-Pallidum_change_pred               0.289197     0.017471        0.576921
# Right-Hippocampus_change_pred            0.486434    -0.093942        0.500003
# Right-Amygdala_change_pred               0.354133    -0.240748        0.326914
# Right-Accumbens-area_change_pred         0.508403     0.045982        0.559019

# %%
# a,_ = np.histogram(corr_result[1][0,:,1], 20)
a,_ = np.histogram(corr_result[0][2,:,1], 20)
# a,_ = np.histogram(corr_result[1][5,:,1], 20)
# a,_ = np.histogram(corr_result[0][1,:,1], 20)
# a,_ = np.histogram(corr_result[0][6,:,1], 20)

# %%
from scipy.stats import chisquare
st, p = chisquare(a, f_exp=None)
p

# %%
titles = ["MCI vs non-MCI", "non-MCI vs HC", "MCI vs HC"]
stats = [MCIvsnonMCI_stats, nonMCIvsHC_stats, MCIvsHC_stats]

for i in range(3):
    f, ax = plt.subplots(nrows=2, ncols=n_regions, figsize=(30, 15))
    f.suptitle(titles[i])
    for j in range(n_regions):
        ax[0,j].set_title(target_columns[j] + " t-stat")
        ax[0,j] = sns.histplot(stats[i][j, :, 0], ax=ax[0,j])
        ax[1,j].set_title(target_columns[j] + " p-value")
        ax[1,j] = sns.histplot(np.cumsum(stats[i][j, :, 1]), ax=ax[1,j])

# %%
target_columns
# Out:
# ['Thalamus_change_pred',
#  'Caudate_change_pred',
#  'Putamen_change_pred',
#  'Pallidum_change_pred',
#  'Hippocampus_change_pred',
#  'Amygdala_change_pred',
#  'Accumbens-area_change_pred']
